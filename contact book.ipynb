# %%
class ContactBook:
    def __init__(self):
        self.contacts = {}

    def add_contact(self, name, phone, email, address):
        if name in self.contacts:
            print("Contact already exists.")
        else:
            self.contacts[name] = {'Phone': phone, 'Email': email, 'Address': address}
            print("Contact added.")

    def view_contacts(self):
        for name, details in self.contacts.items():
            print(f"Name: {name}, Phone: {details['Phone']}, Email: {details['Email']}, Address: {details['Address']}")

    def search_contact(self, search_term):
        found = False
        for name, details in self.contacts.items():
            if search_term in name or search_term in details['Phone']:
                print(f"Name: {name}, Phone: {details['Phone']}, Email: {details['Email']}, Address: {details['Address']}")
                found = True
        if not found:
            print("No contact found.")

    def update_contact(self, name, phone=None, email=None, address=None):
        if name not in self.contacts:
            print("Contact not found.")
        else:
            if phone:
                self.contacts[name]['Phone'] = phone
            if email:
                self.contacts[name]['Email'] = email
            if address:
                self.contacts[name]['Address'] = address
            print("Contact updated.")

    def delete_contact(self, name):
        if name in self.contacts:
            del self.contacts[name]
            print("Contact deleted.")
        else:
            print("Contact not found.")

def main():
    book = ContactBook()
    while True:
        print("\nContact Book Menu:")
        print("1. Add Contact")
        print("2. View Contacts")
        print("3. Search Contact")
        print("4. Update Contact")
        print("5. Delete Contact")
        print("6. Exit")
        choice = input("Enter choice: ")

        if choice == '1':
            name = input("Enter name: ")
            phone = input("Enter phone number: ")
            email = input("Enter email: ")
            address = input("Enter address: ")
            book.add_contact(name, phone, email, address)
        elif choice == '2':
            book.view_contacts()
        elif choice == '3':
            search_term = input("Enter name or phone number to search: ")
            book.search_contact(search_term)
        elif choice == '4':
            name = input("Enter the name of the contact to update: ")
            phone = input("Enter new phone number (leave blank if unchanged): ")
            email = input("Enter new email (leave blank if unchanged): ")
            address = input("Enter new address (leave blank if unchanged): ")
            book.update_contact(name, phone, email, address)
        elif choice == '5':
            name = input("Enter the name of the contact to delete: ")
            book.delete_contact(name)
        elif choice == '6':
            print("Exiting the program.")
            break
        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()
# Out:
# Contact Book Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter choice: 1
# Enter name: nesha
# Enter phone number: 8976546789
# Enter email: nesha@gmail.com
# Enter address: chennai
# Contact added.
#
# Contact Book Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter choice: 1
# Enter name: nivas
# Enter phone number: 9876543456
# Enter email: nivas@gmail.com
# Enter address: madurai
# Contact added.
#
# Contact Book Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter choice: 2
# Name: nesha, Phone: 8976546789, Email: nesha@gmail.com, Address: chennai
# Name: nivas, Phone: 9876543456, Email: nivas@gmail.com, Address: madurai
#
# Contact Book Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter choice: 3
# Enter name or phone number to search: nivas
# Name: nivas, Phone: 9876543456, Email: nivas@gmail.com, Address: madurai
#
# Contact Book Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter choice: 5
# Enter the name of the contact to delete: nesha
# Contact deleted.
#
# Contact Book Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter choice: 2
# Name: nivas, Phone: 9876543456, Email: nivas@gmail.com, Address: madurai
#
# Contact Book Menu:
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter choice: 6
# Exiting the program.
